# %%
from stix2 import Indicator
from stix2 import Bundle
indicators = []

for _ in range(5):
    indicators.append(Indicator(name="File hash for malware variant",
                        pattern="[file:hashes.md5 = 'd41d8cd98f00b204e9800998ecf8427e']",
                        pattern_type="stix"))
    bundle = Bundle(*indicators)
print(bundle)
# Out:
# {
#     "type": "bundle",
#     "id": "bundle--79c1c84e-f806-4802-a0c9-8106a2c3a6ef",
#     "objects": [
#         {
#             "type": "indicator",
#             "spec_version": "2.1",
#             "id": "indicator--fcf57fb1-b736-4645-9bec-53458439e589",
#             "created": "2020-09-01T10:07:31.013474Z",
#             "modified": "2020-09-01T10:07:31.013474Z",
#             "name": "File hash for malware variant",
#             "pattern": "[file:hashes.md5 = 'd41d8cd98f00b204e9800998ecf8427e']",
#             "pattern_type": "stix",
#             "pattern_version": "2.1",
#             "valid_from": "2020-09-01T10:07:31.013474Z"
#         },
#         {
#             "type": "indicator",
#             "spec_version": "2.1",
#             "id": "indicator--3fe74072-dd4f-42af-b2d2-a5ce786ea1be",
#             "created": "2020-09-01T10:07:31.015125Z",
#             "modified": "2020-09-01T10:07:31.015125Z",
#             "name": "File hash for malware variant",
#             "pattern": "[file:hashes.md5 = 'd41d8cd98f00b204e9800998ecf8427e']",
#             "pattern_type": "stix",
#             "pattern_version": "2.1",
#             "valid_from": "2020-09-01T10:07:31.015125Z"
#         },
#         {
#             "type": "indicator",
#             "spec_version": "2.1",
#             "id": "indicator--e68d7c43-5bef-41aa-ae3d-74b4ac8c69d7",
#             "created": "2020-09-01T10:07:31.016513Z",
#             "modified": "2020-09-01T10:07:31.016513Z",
#             "name": "File hash for malware variant",
#             "pattern": "[file:hashes.md5 = 'd41d8cd98f00b204e9800998ecf8427e']",
#             "pattern_type": "stix",
#             "pattern_version": "2.1",
#             "valid_from": "2020-09-01T10:07:31.016513Z"
#         },
#         {
#             "type": "indicator",
#             "spec_version": "2.1",
#             "id": "indicator--ad7676b1-8f3e-4bb5-ab37-94b84a28efc5",
#             "created": "2020-09-01T10:07:31.017831Z",
#             "modified": "2020-09-01T10:07:31.017831Z",
#             "name": "File hash for malware variant",
#             "pattern": "[file:hashes.md5 = 'd41d8cd98f00b204e9800998ecf8427e']",
#             "pattern_type": "stix",
#             "pattern_version": "2.1",
#             "valid_from": "2020-09-01T10:07:31.017831Z"
#         },
#         {
#             "type": "indicator",
#             "spec_version": "2.1",
#             "id": "indicator--afb59e85-7ae3-4f09-9a43-13e219931945",
#             "created": "2020-09-01T10:07:31.019145Z",
#             "modified": "2020-09-01T10:07:31.019145Z",
#             "name": "File hash for malware variant",
#             "pattern": "[file:hashes.md5 = 'd41d8cd98f00b204e9800998ecf8427e']",
#             "pattern_type": "stix",
#             "pattern_version": "2.1",
#             "valid_from": "2020-09-01T10:07:31.019145Z"
#         }
#     ]
# }

# %%
json_str = """{
  "id": 295,
  "name": "type",
  "text": "Type",
  "prefix": null,
  "type_id": 4,
  "input_type": "select",
  "hide_notification": false,
  "chosen": false,
  "default_chosen_by_server": false,
  "blank_option": false,
  "internal": true,
  "uuid": "25dd5ae3-549b-4114-a9b6-64ef7baef80c",
  "operations": [
    "equals",
    "has_a_value",
    "in",
    "not_equals",
    "not_has_a_value",
    "not_in"
  ],
  "operation_perms": {
    "equals": {
      "show_in_manual_actions": true,
      "show_in_auto_actions": true,
      "show_in_notifications": true
    },
    "has_a_value": {
      "show_in_manual_actions": true,
      "show_in_auto_actions": true,
      "show_in_notifications": true
    },
    "in": {
      "show_in_manual_actions": true,
      "show_in_auto_actions": true,
      "show_in_notifications": true
    },
    "not_equals": {
      "show_in_manual_actions": true,
      "show_in_auto_actions": true,
      "show_in_notifications": true
    },
    "not_has_a_value": {
      "show_in_manual_actions": true,
      "show_in_auto_actions": true,
      "show_in_notifications": true
    },
    "not_in": {
      "show_in_manual_actions": true,
      "show_in_auto_actions": true,
      "show_in_notifications": true
    }
  },
  "values": [
    {
      "value": 2,
      "label": "DNS 名稱",
      "enabled": true,
      "properties": {
        "allow_duplicate": false
      },
      "uuid": "5b48edb6-786b-46b8-a619-3da03a8adb0d",
      "hidden": false,
      "default": false
    },
    {
      "value": 1080,
      "label": "email address",
      "enabled": true,
      "properties": {
        "allow_duplicate": false
      },
      "uuid": "e5d1ea35-f939-433e-8935-c2127dd7292e",
      "hidden": false,
      "default": false
    },
    {
      "value": 35,
      "label": "HTTP 回應標頭",
      "enabled": true,
      "properties": {
        "allow_duplicate": false
      },
      "uuid": "7e91455b-0c82-433f-a6ea-55f159cc67a8",
      "hidden": false,
      "default": false
    },
    {
      "value": 34,
      "label": "HTTP 要求標頭",
      "enabled": true,
      "properties": {
        "allow_duplicate": false
      },
      "uuid": "0c7addee-88ef-4c7a-a648-57864fdd75b9",
      "hidden": false,
      "default": false
    },
    {
      "value": 1,
      "label": "IP 位址",
      "enabled": true,
      "properties": {
        "allow_duplicate": false
      },
      "uuid": "cfd8139b-e238-4447-b857-6f1047ddbac3",
      "hidden": false,
      "default": false
    },
    {
      "value": 1082,
      "label": "Is NTHU",
      "enabled": true,
      "properties": {
        "allow_duplicate": false
      },
      "uuid": "f54ad2b4-f54e-4e23-87bb-d7923ca3fa1c",
      "hidden": false,
      "default": false
    },
    {
      "value": 39,
      "label": "MAC 位址",
      "enabled": true,
      "properties": {
        "allow_duplicate": false
      },
      "uuid": "9d08fbd9-e3b8-46c3-974c-9ffcc215232c",
      "hidden": false,
      "default": false
    },
    {
      "value": 4,
      "label": "RFC 822 電子郵件訊息檔案",
      "enabled": true,
      "properties": {
        "allow_duplicate": true
      },
      "uuid": "0097498b-4f19-41f7-9e13-267de362dbe5",
      "hidden": false,
      "default": false
    },
    {
      "value": 1084,
      "label": "STIX bundle",
      "enabled": true,
      "properties": {
        "allow_duplicate": true
      },
      "uuid": "b405847e-d84e-4f32-8c82-1b8c23a9cbbb",
      "hidden": false,
      "default": false
    },
    {
      "value": 42,
      "label": "URI 路徑",
      "enabled": true,
      "properties": {
        "allow_duplicate": false
      },
      "uuid": "498431b8-cc8b-445e-9aa9-b2a4715bbf66",
      "hidden": false,
      "default": false
    },
    {
      "value": 3,
      "label": "URL",
      "enabled": true,
      "properties": {
        "allow_duplicate": false
      },
      "uuid": "ee907a44-acbc-4769-83f3-f1f4097b74c2",
      "hidden": false,
      "default": false
    },
    {
      "value": 40,
      "label": "URL 參照者",
      "enabled": true,
      "properties": {
        "allow_duplicate": false
      },
      "uuid": "ac729a57-2f4a-48f9-a476-c0e0c76c0f38",
      "hidden": false,
      "default": false
    },
    {
      "value": 36,
      "label": "X509 憑證檔案",
      "enabled": true,
      "properties": {
        "allow_duplicate": true
      },
      "uuid": "0a76fa64-b3a3-40a2-9b16-0d4f52abfb2e",
      "hidden": false,
      "default": false
    },
    {
      "value": 30,
      "label": "互斥旗標",
      "enabled": true,
      "properties": {
        "allow_duplicate": false
      },
      "uuid": "433ea6b1-a30a-4738-9ee6-5c29c84c7d63",
      "hidden": false,
      "default": false
    },
    {
      "value": 41,
      "label": "使用者代理程式",
      "enabled": true,
      "properties": {
        "allow_duplicate": false
      },
      "uuid": "4a2ee4d6-71f4-4958-9964-818e0b159554",
      "hidden": false,
      "default": false
    },
    {
      "value": 23,
      "label": "使用者帳戶",
      "enabled": true,
      "properties": {
        "allow_duplicate": false
      },
      "uuid": "4bce2b51-2784-4f2a-8d9d-185d8c32fef5",
      "hidden": false,
      "default": false
    },
    {
      "value": 16,
      "label": "其他檔案",
      "enabled": true,
      "properties": {
        "allow_duplicate": true
      },
      "uuid": "ccaef8b6-a97a-40ce-9583-34972ff8adb6",
      "hidden": false,
      "default": false
    },
    {
      "value": 27,
      "label": "埠",
      "enabled": true,
      "properties": {
        "allow_duplicate": false
      },
      "uuid": "29ddb871-05a9-4059-aacc-fd41771b773a",
      "hidden": false,
      "default": false
    },
    {
      "value": 43,
      "label": "威脅 CVE ID",
      "enabled": true,
      "properties": {
        "allow_duplicate": false
      },
      "uuid": "dc9b914b-d7b3-42aa-ac35-0ce047082bd0",
      "hidden": false,
      "default": false
    },
    {
      "value": 29,
      "label": "字串",
      "enabled": true,
      "properties": {
        "allow_duplicate": false
      },
      "uuid": "5d84b420-24ac-431f-b383-ae4b12039371",
      "hidden": false,
      "default": false
    },
    {
      "value": 32,
      "label": "密碼",
      "enabled": true,
      "properties": {
        "allow_duplicate": false
      },
      "uuid": "42c74133-2744-4f0e-a8b5-db5da359f54c",
      "hidden": false,
      "default": false
    },
    {
      "value": 46,
      "label": "已觀察到的資料",
      "enabled": true,
      "properties": {
        "allow_duplicate": true
      },
      "uuid": "6070290a-5cb8-11ea-bc55-0242ac130003",
      "hidden": false,
      "default": false
    },
    {
      "value": 13,
      "label": "惡意軟體 MD5 雜湊",
      "enabled": true,
      "properties": {
        "allow_duplicate": false
      },
      "uuid": "b3c08b46-52a7-4e6f-8d6d-d999350252a6",
      "hidden": false,
      "default": false
    },
    {
      "value": 14,
      "label": "惡意軟體 SHA-1 雜湊",
      "enabled": true,
      "properties": {
        "allow_duplicate": false
      },
      "uuid": "961f185a-76aa-46e5-8c05-83246c860be7",
      "hidden": false,
      "default": false
    },
    {
      "value": 38,
      "label": "惡意軟體 SHA-256 雜湊",
      "enabled": true,
      "properties": {
        "allow_duplicate": false
      },
      "uuid": "bc24bc52-eca2-4cd1-9488-2818fc0aa5e9",
      "hidden": false,
      "default": false
    },
    {
      "value": 12,
      "label": "惡意軟體樣本",
      "enabled": true,
      "properties": {
        "allow_duplicate": false
      },
      "uuid": "c97dee7e-4098-46fe-866e-5d67ea7eb17a",
      "hidden": false,
      "default": false
    },
    {
      "value": 22,
      "label": "惡意軟體樣本模糊雜湊",
      "enabled": true,
      "properties": {
        "allow_duplicate": false
      },
      "uuid": "8bd99af1-6434-4c80-bdfc-4a4f9c22fef0",
      "hidden": false,
      "default": false
    },
    {
      "value": 45,
      "label": "惡意軟體系列/變式",
      "enabled": true,
      "properties": {
        "allow_duplicate": false
      },
      "uuid": "0e28d76d-14cc-45bb-afc8-871753f455f3",
      "hidden": false,
      "default": false
    },
    {
      "value": 15,
      "label": "日誌檔",
      "enabled": true,
      "properties": {
        "allow_duplicate": true
      },
      "uuid": "e3e2b702-31f5-4a6c-a1c7-83da91d5f47d",
      "hidden": false,
      "default": false
    },
    {
      "value": 28,
      "label": "服務",
      "enabled": true,
      "properties": {
        "allow_duplicate": false
      },
      "uuid": "a4e95d95-de57-4fc9-96db-2098230fce77",
      "hidden": false,
      "default": false
    },
    {
      "value": 31,
      "label": "檔名",
      "enabled": true,
      "properties": {
        "allow_duplicate": false
      },
      "uuid": "7cea41a7-d0e0-4f3a-922a-f8bb2dec5918",
      "hidden": false,
      "default": false
    },
    {
      "value": 37,
      "label": "檔案路徑",
      "enabled": true,
      "properties": {
        "allow_duplicate": false
      },
      "uuid": "2146c562-af15-4f18-9951-41221327738c",
      "hidden": false,
      "default": false
    },
    {
      "value": 24,
      "label": "登錄機碼",
      "enabled": true,
      "properties": {
        "allow_duplicate": false
      },
      "uuid": "ba483ed2-3efb-4112-bb4f-fdce5f4557cc",
      "hidden": false,
      "default": false
    },
    {
      "value": 26,
      "label": "程序名稱",
      "enabled": true,
      "properties": {
        "allow_duplicate": false
      },
      "uuid": "521e33db-2baf-43aa-8c6d-4fd59a0deb3d",
      "hidden": false,
      "default": false
    },
    {
      "value": 25,
      "label": "系統名稱",
      "enabled": true,
      "properties": {
        "allow_duplicate": false
      },
      "uuid": "023e705f-efe2-4fe1-acd9-10d75f701b28",
      "hidden": false,
      "default": false
    },
    {
      "value": 44,
      "label": "網路 CIDR 範圍",
      "enabled": true,
      "properties": {
        "allow_duplicate": false
      },
      "uuid": "45f86562-ad6d-4db6-aa35-6cca238bf949",
      "hidden": false,
      "default": false
    },
    {
      "value": 5,
      "label": "電子郵件主旨",
      "enabled": true,
      "properties": {
        "allow_duplicate": false
      },
      "uuid": "9423920e-aaa4-469a-8b19-c60c081e25a1",
      "hidden": false,
      "default": false
    },
    {
      "value": 6,
      "label": "電子郵件內文",
      "enabled": true,
      "properties": {
        "allow_duplicate": false
      },
      "uuid": "a8f07db2-65d3-4f81-b0d1-c0d564af84ff",
      "hidden": false,
      "default": false
    },
    {
      "value": 9,
      "label": "電子郵件寄件者",
      "enabled": true,
      "properties": {
        "allow_duplicate": false
      },
      "uuid": "94def29c-cf7e-4bd6-af96-d1e14133de67",
      "hidden": false,
      "default": false
    },
    {
      "value": 19,
      "label": "電子郵件寄件者名稱",
      "enabled": true,
      "properties": {
        "allow_duplicate": false
      },
      "uuid": "9b9d155f-2459-4724-9cb3-dc64f9347b41",
      "hidden": false,
      "default": false
    },
    {
      "value": 20,
      "label": "電子郵件收件者",
      "enabled": true,
      "properties": {
        "allow_duplicate": false
      },
      "uuid": "3517c291-ab54-4c23-b55d-b677b2d9be2f",
      "hidden": false,
      "default": false
    },
    {
      "value": 7,
      "label": "電子郵件附件",
      "enabled": true,
      "properties": {
        "allow_duplicate": true
      },
      "uuid": "310e4f8d-1a55-4cea-b28e-2aa73c1758c5",
      "hidden": false,
      "default": false
    },
    {
      "value": 8,
      "label": "電子郵件附件名稱",
      "enabled": true,
      "properties": {
        "allow_duplicate": false
      },
      "uuid": "1a085796-7dd9-4e68-b689-32ea6d6c2c42",
      "hidden": false,
      "default": false
    }
  ],
  "perms": {
    "delete": false,
    "modify_name": false,
    "modify_values": false,
    "modify_blank": false,
    "modify_required": false,
    "modify_operations": false,
    "modify_chosen": false,
    "modify_default": false,
    "show_in_manual_actions": true,
    "show_in_auto_actions": true,
    "show_in_notifications": true,
    "show_in_scripts": true,
    "modify_type": [
      "select"
    ],
    "sort": true
  },
  "read_only": true,
  "changeable": false,
  "rich_text": false,
  "templates": [],
  "deprecated": false,
  "tags": [],
  "calculated": false,
  "is_tracked": false,
  "allow_default_value": false
}"""

# %%
import json
j = json.loads(json_str)
csv_str = "\n".join([str(v["value"])+","+v["label"] for v in j['values']])
with open('/Users/chaowen/Desktop/stix-mapping.csv', 'w') as f:
    f.write(csv_str)

# %%
import pandas as pd
pd.read_csv('/Users/chaowen/Desktop/stix-mapping.csv', encoding='utf-8')
# Out:
#        2            DNS 名稱
# 0   1080     email address
# 1     35         HTTP 回應標頭
# 2     34         HTTP 要求標頭
# 3      1             IP 位址
# 4   1082           Is NTHU
# 5     39            MAC 位址
# 6      4  RFC 822 電子郵件訊息檔案
# 7   1084       STIX bundle
# 8     42            URI 路徑
# 9      3               URL
# 10    40           URL 參照者
# 11    36         X509 憑證檔案
# 12    30              互斥旗標
# 13    41           使用者代理程式
# 14    23             使用者帳戶
# 15    16              其他檔案
# 16    27                 埠
# 17    43         威脅 CVE ID
# 18    29                字串
# 19    32                密碼
# 20    46           已觀察到的資料
# 21    13       惡意軟體 MD5 雜湊
# 22    14     惡意軟體 SHA-1 雜湊
# 23    38   惡意軟體 SHA-256 雜湊
# 24    12            惡意軟體樣本
# 25    22        惡意軟體樣本模糊雜湊
# 26    45         惡意軟體系列/變式
# 27    15               日誌檔
# 28    28                服務
# 29    31                檔名
# 30    37              檔案路徑
# 31    24              登錄機碼
# 32    26              程序名稱
# 33    25              系統名稱
# 34    44        網路 CIDR 範圍
# 35     5            電子郵件主旨
# 36     6            電子郵件內文
# 37     9           電子郵件寄件者
# 38    19         電子郵件寄件者名稱
# 39    20           電子郵件收件者
# 40     7            電子郵件附件
# 41     8          電子郵件附件名稱
